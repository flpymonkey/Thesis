# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
# import condacolab
# condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
# TODO, remove DOW from training as it is missing some values in 2019
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

# TRAIN_START_DATE = '2010-01-01'
# TRAIN_END_DATE = '2021-10-01'
# TEST_START_DATE = '2021-10-01'
# TEST_END_DATE = '2023-03-01'
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.config_tickers import DOW_30_TICKER


# TODO Drop the DOW stock
value_to_remove = "DOW"
# Create a new list without the specified string
DOW_30_TICKER = [x for x in DOW_30_TICKER if x != value_to_remove]
print(DOW_30_TICKER)

# TODO try different date ranges
# TRAIN_START_DATE = '2009-01-01'
# TRAIN_END_DATE = '2018-10-01'
# TEST_START_DATE = '2018-10-01'
# TEST_END_DATE = '2021-03-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS']
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (96135, 8)

# %%
INDICATORS = ['macd',
            'rsi_30',
            'cci_30',
            'dx_30']

# %%
from finrl.meta.preprocessor.preprocessors import FeatureEngineer
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)

# here you can see the engineered features are added to each stock day
print(processed)

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 175

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS, # TODO we pass these in and set the environment
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity":5

}

# buy_cost_list = sell_cost_list = [0.001] * stock_dimension
# num_stock_shares = [0] * stock_dimension
# env_kwargs = {
#     "hmax": 100,
#     "initial_amount": 1000000,
#     "num_stock_shares": num_stock_shares,
#     "buy_cost_pct": buy_cost_list,
#     "sell_cost_pct": sell_cost_list,
#     "state_space": state_space,
#     "stock_dim": stock_dimension,
#     "tech_indicator_list": INDICATORS,
#     "action_space": stock_dimension,
#     "reward_scaling": 1e-4
# }

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

# TODO here we pass in the engineered features along with the stock data
ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **env_kwargs)
# e_train_gym = StockTradingEnv(df = processed, **env_kwargs)
# agent = DRLAgent(e_train_gym)
# if_using_a2c = True
# model_a2c = agent.get_model("a2c")
# # if if_using_a2c:
# #   tmp_path = RESULTS_DIR + '/a2c'
# #   new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# #   model_a2c.set_logger(new_logger_a2c)
# trained_a2c = agent.train_model(model=model_a2c,
#                              tb_log_name='a2c',
#                              total_timesteps=50000)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
    "batch_size": 64,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

TD3_model_kwargs = {"batch_size": 100, "buffer_size": 1000000, "learning_rate": 0.0001}




timesteps_dict = {'a2c' : 10_000,
                 'ppo' : 10_000,
                 'ddpg' : 10_000,
                 'sac' : 10_000,
                 'td3' : 10_000
                 }

# %%
# # Uncomment this to actually train a new model
# df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  SAC_model_kwargs,
#                                                  TD3_model_kwargs,
#                                                  timesteps_dict)

# df_summary
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  203.40433015366023
# ======Model training from:  2009-04-01 to  2021-01-04
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_8
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 24         |
# |    reward             | 0.14363284 |
# |    std                | 1          |
# |    value_loss         | 2.15       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 200       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 46.3      |
# |    reward             | 1.7603092 |
# |    std                | 0.998     |
# |    value_loss         | 1.53      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 300      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -244     |
# |    reward             | 4.010841 |
# |    std                | 0.996    |
# |    value_loss         | 33.7     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 400        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 35.1       |
# |    reward             | 0.35331497 |
# |    std                | 0.997      |
# |    value_loss         | 5.06       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 500        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 194        |
# |    reward             | -1.3262545 |
# |    std                | 0.995      |
# |    value_loss         | 26.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 600        |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -25.9      |
# |    reward             | 0.33334354 |
# |    std                | 0.995      |
# |    value_loss         | 0.45       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 76         |
# |    iterations         | 700        |
# |    time_elapsed       | 45         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -0.274     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -76.3      |
# |    reward             | -0.9936582 |
# |    std                | 0.996      |
# |    value_loss         | 4.3        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 73          |
# |    iterations         | 800         |
# |    time_elapsed       | 54          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 30.4        |
# |    reward             | 0.035063088 |
# |    std                | 0.996       |
# |    value_loss         | 0.876       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 70        |
# |    iterations         | 900       |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 22.6      |
# |    reward             | 2.2066586 |
# |    std                | 0.996     |
# |    value_loss         | 2.01      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 69         |
# |    iterations         | 1000       |
# |    time_elapsed       | 72         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -0.179     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -56.3      |
# |    reward             | 0.19014364 |
# |    std                | 0.994      |
# |    value_loss         | 2.82       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 67         |
# |    iterations         | 1100       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -0.049     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -98.4      |
# |    reward             | -1.1426626 |
# |    std                | 0.994      |
# |    value_loss         | 12.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 1200       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 97.3       |
# |    reward             | -0.3993066 |
# |    std                | 0.993      |
# |    value_loss         | 6.41       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 65        |
# |    iterations         | 1300      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -76       |
# |    reward             | 1.0485797 |
# |    std                | 0.992     |
# |    value_loss         | 6.23      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 65        |
# |    iterations         | 1400      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 119       |
# |    reward             | 1.3484524 |
# |    std                | 0.991     |
# |    value_loss         | 15.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 64        |
# |    iterations         | 1500      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -40.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -66.1     |
# |    reward             | 3.7438648 |
# |    std                | 0.989     |
# |    value_loss         | 8.24      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 63        |
# |    iterations         | 1600      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | 0.132     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 157       |
# |    reward             | -2.273112 |
# |    std                | 0.991     |
# |    value_loss         | 15.9      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 63          |
# |    iterations         | 1700        |
# |    time_elapsed       | 134         |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -40.9       |
# |    explained_variance | -0.066      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | -0.474      |
# |    reward             | -0.11013231 |
# |    std                | 0.993       |
# |    value_loss         | 3.36        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 62       |
# |    iterations         | 1800     |
# |    time_elapsed       | 143      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -40.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 56.1     |
# |    reward             | 0.556566 |
# |    std                | 0.993    |
# |    value_loss         | 2.19     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 62        |
# |    iterations         | 1900      |
# |    time_elapsed       | 152       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -33.2     |
# |    reward             | 2.2833478 |
# |    std                | 0.993     |
# |    value_loss         | 5.36      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 61         |
# |    iterations         | 2000       |
# |    time_elapsed       | 161        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 7.5        |
# |    reward             | 0.23867315 |
# |    std                | 0.993      |
# |    value_loss         | 0.507      |
# --------------------------------------
# ======a2c Validation from:  2021-01-04 to  2021-04-06
# a2c Sharpe Ratio:  0.43592638878112006
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_8
# day: 2959, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4022731.97
# total_reward: 3022731.97
# total_cost: 4543.62
# total_trades: 62730
# Sharpe: 0.745
# =================================
# ======ddpg Validation from:  2021-01-04 to  2021-04-06
# ddpg Sharpe Ratio:  0.37648377089877516
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cpu device
# Logging to tensorboard_log/td3\td3_126_8
# day: 2959, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5328830.98
# total_reward: 4328830.98
# total_cost: 1110.20
# total_trades: 41425
# Sharpe: 0.827
# =================================
# ======td3 Validation from:  2021-01-04 to  2021-04-06
# td3 Sharpe Ratio:  0.3065715297806941
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac\sac_126_8
# day: 2959, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 6119461.55
# total_reward: 5119461.55
# total_cost: 113697.92
# total_trades: 54316
# Sharpe: 0.974
# =================================
# ======sac Validation from:  2021-01-04 to  2021-04-06
# sac Sharpe Ratio:  0.25375462359343054
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_8
# ----------------------------------
# | time/              |           |
# |    fps             | 66        |
# |    iterations      | 1         |
# |    time_elapsed    | 30        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.2838207 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 2           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014231674 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0183     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.84        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0251     |
# |    reward               | 0.62129134  |
# |    std                  | 1           |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 3           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.020615267 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00216     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0132     |
# |    reward               | -0.13020772 |
# |    std                  | 1           |
# |    value_loss           | 69.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 4           |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015259808 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0107     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0221     |
# |    reward               | -3.762212   |
# |    std                  | 1.01        |
# |    value_loss           | 58.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 5          |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01616494 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | -0.0211    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 10.7       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0215    |
# |    reward               | 1.0730193  |
# |    std                  | 1.01       |
# |    value_loss           | 28.6       |
# ----------------------------------------
# ======ppo Validation from:  2021-01-04 to  2021-04-06
# ppo Sharpe Ratio:  0.26421587135792096
# ======Best Model Retraining from:  2009-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  203.40433015366023
# ======Model training from:  2009-04-01 to  2021-04-06
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_8
# ---------------------------------------
# | time/                 |             |
# |    fps                | 56          |
# |    iterations         | 100         |
# |    time_elapsed       | 8           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.0545      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -10.7       |
# |    reward             | -0.13776396 |
# |    std                | 1           |
# |    value_loss         | 3.54        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 200       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 77.9      |
# |    reward             | 2.4769351 |
# |    std                | 1         |
# |    value_loss         | 4.3       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 300       |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -250      |
# |    reward             | 3.9064078 |
# |    std                | 1         |
# |    value_loss         | 44.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 400        |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -31.3      |
# |    reward             | 0.49339163 |
# |    std                | 1          |
# |    value_loss         | 12.1       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 56          |
# |    iterations         | 500         |
# |    time_elapsed       | 44          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 406         |
# |    reward             | -0.06729528 |
# |    std                | 1           |
# |    value_loss         | 126         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 600       |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.15e+03  |
# |    reward             | 7.1863823 |
# |    std                | 1         |
# |    value_loss         | 716       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 700        |
# |    time_elapsed       | 62         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.000363  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | 22         |
# |    reward             | -4.2272205 |
# |    std                | 1          |
# |    value_loss         | 1.02       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 800       |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 13.4      |
# |    reward             | 1.1027429 |
# |    std                | 1         |
# |    value_loss         | 3.26      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 900       |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 215       |
# |    reward             | 1.5592983 |
# |    std                | 1         |
# |    value_loss         | 34.3      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 55       |
# |    iterations         | 1000     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -176     |
# |    reward             | 3.544901 |
# |    std                | 1        |
# |    value_loss         | 30.8     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 1100       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 47.1       |
# |    reward             | 14.0949955 |
# |    std                | 1          |
# |    value_loss         | 32         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 1200      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 58.3      |
# |    reward             | 2.3266613 |
# |    std                | 1         |
# |    value_loss         | 24.6      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 54          |
# |    iterations         | 1300        |
# |    time_elapsed       | 118         |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | 15.3        |
# |    reward             | -0.78422153 |
# |    std                | 1           |
# |    value_loss         | 0.186       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 54        |
# |    iterations         | 1400      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -43       |
# |    reward             | 0.5621494 |
# |    std                | 1         |
# |    value_loss         | 4.93      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 54         |
# |    iterations         | 1500       |
# |    time_elapsed       | 136        |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.00539    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -168       |
# |    reward             | -3.4265263 |
# |    std                | 1          |
# |    value_loss         | 17.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 54        |
# |    iterations         | 1600      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.0332   |
# |    reward             | 1.7441788 |
# |    std                | 1         |
# |    value_loss         | 0.181     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 54        |
# |    iterations         | 1700      |
# |    time_elapsed       | 154       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 4.36e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -1.06e+03 |
# |    reward             | 7.660182  |
# |    std                | 1.01      |
# |    value_loss         | 633       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 54        |
# |    iterations         | 1800      |
# |    time_elapsed       | 163       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -316      |
# |    reward             | 1.4078097 |
# |    std                | 1.01      |
# |    value_loss         | 69.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 54         |
# |    iterations         | 1900       |
# |    time_elapsed       | 173        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -54.4      |
# |    reward             | -1.1288623 |
# |    std                | 1.01       |
# |    value_loss         | 1.95       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 54         |
# |    iterations         | 2000       |
# |    time_elapsed       | 182        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -14.8      |
# |    reward             | 0.53105587 |
# |    std                | 1.01       |
# |    value_loss         | 0.493      |
# --------------------------------------
# ======a2c Validation from:  2021-04-06 to  2021-07-06
# a2c Sharpe Ratio:  0.05797248722292804
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_8
# day: 3022, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 5988371.34
# total_reward: 4988371.34
# total_cost: 4747.91
# total_trades: 63988
# Sharpe: 0.947
# =================================
# ======ddpg Validation from:  2021-04-06 to  2021-07-06
# ddpg Sharpe Ratio:  0.046928737089548055
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cpu device
# Logging to tensorboard_log/td3\td3_189_8
# day: 3022, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 7055727.49
# total_reward: 6055727.49
# total_cost: 1803.42
# total_trades: 51259
# Sharpe: 0.905
# =================================
# ======td3 Validation from:  2021-04-06 to  2021-07-06
# td3 Sharpe Ratio:  0.18261217274465832
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac\sac_189_8
# day: 3022, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 7840861.00
# total_reward: 6840861.00
# total_cost: 89895.00
# total_trades: 54456
# Sharpe: 0.989
# =================================
# ======sac Validation from:  2021-04-06 to  2021-07-06
# sac Sharpe Ratio:  0.18730928824540188
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_8
# ----------------------------------
# | time/              |           |
# |    fps             | 64        |
# |    iterations      | 1         |
# |    time_elapsed    | 31        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.8423867 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 2           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016306091 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00408    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.2         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0257     |
# |    reward               | 0.47016832  |
# |    std                  | 1           |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 3           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.020118736 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00365    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0213     |
# |    reward               | 0.3256591   |
# |    std                  | 1           |
# |    value_loss           | 41.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 4           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014596997 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0121     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0125     |
# |    reward               | -0.2917636  |
# |    std                  | 1           |
# |    value_loss           | 75.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 5           |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017101288 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0179     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0229     |
# |    reward               | 0.9890208   |
# |    std                  | 1.01        |
# |    value_loss           | 24.8        |
# -----------------------------------------
# ======ppo Validation from:  2021-04-06 to  2021-07-06
# ppo Sharpe Ratio:  0.09559201071849044
# ======Best Model Retraining from:  2009-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  203.40433015366023
# ======Model training from:  2009-04-01 to  2021-07-06
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_8
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.00305  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -6.35     |
# |    reward             | 0.2840119 |
# |    std                | 0.998     |
# |    value_loss         | 5.56      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 44.7      |
# |    reward             | 1.6796529 |
# |    std                | 0.999     |
# |    value_loss         | 1.86      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 300       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -194      |
# |    reward             | 3.3399673 |
# |    std                | 0.998     |
# |    value_loss         | 24.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 400        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -12.1      |
# |    reward             | 0.27288252 |
# |    std                | 0.999      |
# |    value_loss         | 0.757      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 500       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 25.4      |
# |    reward             | 1.0760809 |
# |    std                | 0.999     |
# |    value_loss         | 0.529     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 600        |
# |    time_elapsed       | 34         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -501       |
# |    reward             | -11.398894 |
# |    std                | 1          |
# |    value_loss         | 226        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 700       |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.000697  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -103      |
# |    reward             | 0.7064597 |
# |    std                | 1         |
# |    value_loss         | 6.21      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 800        |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -335       |
# |    reward             | -2.8614905 |
# |    std                | 1          |
# |    value_loss         | 70.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 900        |
# |    time_elapsed       | 56         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 92.8       |
# |    reward             | 0.15958494 |
# |    std                | 1          |
# |    value_loss         | 8.27       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 75          |
# |    iterations         | 1000        |
# |    time_elapsed       | 65          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | -121        |
# |    reward             | -0.38287985 |
# |    std                | 1           |
# |    value_loss         | 12.4        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 1100     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | -0.0486  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -568     |
# |    reward             | 7.979469 |
# |    std                | 1        |
# |    value_loss         | 202      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 70         |
# |    iterations         | 1200       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -221       |
# |    reward             | -5.8724155 |
# |    std                | 1          |
# |    value_loss         | 53.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 68         |
# |    iterations         | 1300       |
# |    time_elapsed       | 94         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.0054     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 78.2       |
# |    reward             | -1.3935429 |
# |    std                | 1          |
# |    value_loss         | 4.43       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 67        |
# |    iterations         | 1400      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.937    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -28.3     |
# |    reward             | 2.7984648 |
# |    std                | 1         |
# |    value_loss         | 3.12      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 1500       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 121        |
# |    reward             | 0.77521265 |
# |    std                | 1          |
# |    value_loss         | 7.17       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 65        |
# |    iterations         | 1600      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -191      |
# |    reward             | 2.1331706 |
# |    std                | 1         |
# |    value_loss         | 59.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 64         |
# |    iterations         | 1700       |
# |    time_elapsed       | 132        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -133       |
# |    reward             | -1.4689103 |
# |    std                | 1.01       |
# |    value_loss         | 15.1       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 63       |
# |    iterations         | 1800     |
# |    time_elapsed       | 141      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | -0.00888 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 82.4     |
# |    reward             | 9.717924 |
# |    std                | 1.01     |
# |    value_loss         | 44.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 62        |
# |    iterations         | 1900      |
# |    time_elapsed       | 151       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.666    |
# ...
# |    time_elapsed       | 21         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -1.26      |
# |    reward             | 0.48230088 |
# |    std                | 1          |
# |    value_loss         | 1.57       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 500        |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 189        |
# |    reward             | -0.8450552 |
# |    std                | 1          |
# |    value_loss         | 23         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 600        |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -32.7      |
# |    reward             | -6.6272564 |
# |    std                | 1          |
# |    value_loss         | 19.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 700       |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.038     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -113      |
# |    reward             | -0.782199 |
# |    std                | 1         |
# |    value_loss         | 16.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 800        |
# |    time_elapsed       | 43         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.0108    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 83.7       |
# |    reward             | 0.32799676 |
# |    std                | 1          |
# |    value_loss         | 6.27       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 91        |
# |    iterations         | 900       |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -41.8     |
# |    reward             | 1.4742104 |
# |    std                | 1.01      |
# |    value_loss         | 5.31      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1000       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.143     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 15.5       |
# |    reward             | -0.6696015 |
# |    std                | 1.01       |
# |    value_loss         | 0.929      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1100      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 352       |
# |    reward             | 1.3811308 |
# |    std                | 1.01      |
# |    value_loss         | 77.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 1200      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 224       |
# |    reward             | 2.2699091 |
# |    std                | 1.01      |
# |    value_loss         | 43.9      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 89          |
# |    iterations         | 1300        |
# |    time_elapsed       | 72          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0.0614      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | -80.9       |
# |    reward             | -0.61320615 |
# |    std                | 1.01        |
# |    value_loss         | 4.08        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1400       |
# |    time_elapsed       | 78         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 63.7       |
# |    reward             | 0.67043656 |
# |    std                | 1.01       |
# |    value_loss         | 3.5        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1500       |
# |    time_elapsed       | 83         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.478     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -14.4      |
# |    reward             | -0.5748543 |
# |    std                | 1          |
# |    value_loss         | 0.58       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1600       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.00665   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 47.8       |
# |    reward             | 0.89575523 |
# |    std                | 1          |
# |    value_loss         | 4.68       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1700       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 68.8       |
# |    reward             | 0.09470875 |
# |    std                | 1          |
# |    value_loss         | 3.64       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1800       |
# |    time_elapsed       | 101        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 139        |
# |    reward             | 0.44809666 |
# |    std                | 1          |
# |    value_loss         | 14         |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 88           |
# |    iterations         | 1900         |
# |    time_elapsed       | 107          |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -41.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | -11.9        |
# |    reward             | -0.024110854 |
# |    std                | 1            |
# |    value_loss         | 0.0993       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 2000       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.0178    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -102       |
# |    reward             | -1.8445053 |
# |    std                | 1.01       |
# |    value_loss         | 6.68       |
# --------------------------------------
# ======a2c Validation from:  2021-10-04 to  2022-01-03
# a2c Sharpe Ratio:  0.17043462511263485
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_8
# day: 3148, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4286495.26
# total_reward: 3286495.26
# total_cost: 5016.78
# total_trades: 57681
# Sharpe: 0.747
# =================================
# ======ddpg Validation from:  2021-10-04 to  2022-01-03
# ddpg Sharpe Ratio:  0.12743295316689407
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cpu device
# Logging to tensorboard_log/td3\td3_315_8
# day: 3148, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 7519465.02
# total_reward: 6519465.02
# total_cost: 2309.51
# total_trades: 56094
# Sharpe: 0.955
# =================================
# ======td3 Validation from:  2021-10-04 to  2022-01-03
# td3 Sharpe Ratio:  0.16101492751219731
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac\sac_315_8
# day: 3148, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 6074495.00
# total_reward: 5074495.00
# total_cost: 999.00
# total_trades: 44060
# Sharpe: 0.869
# =================================
# ======sac Validation from:  2021-10-04 to  2022-01-03
# sac Sharpe Ratio:  0.15080403574370824
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_8
# ----------------------------------
# | time/              |           |
# |    fps             | 116       |
# |    iterations      | 1         |
# |    time_elapsed    | 17        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.3830936 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 2           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015310781 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0158     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.29        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0255     |
# |    reward               | 0.62366164  |
# |    std                  | 1           |
# |    value_loss           | 15.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 3           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016605588 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00283    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0113     |
# |    reward               | 7.407186    |
# |    std                  | 1.01        |
# |    value_loss           | 50.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 4           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017037544 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.0117      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0166     |
# |    reward               | -1.0254179  |
# |    std                  | 1.01        |
# |    value_loss           | 61.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 5           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016687334 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.142      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.11        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0244     |
# |    reward               | 0.08086599  |
# |    std                  | 1.01        |
# |    value_loss           | 14.2        |
# -----------------------------------------
# ======ppo Validation from:  2021-10-04 to  2022-01-03
# ppo Sharpe Ratio:  0.039834744921921864
# ======Best Model Retraining from:  2009-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  82.71876746813456  minutes

# %%
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2021-01-04  2021-04-06        A2C   0.435926   0.264216    0.376484
# 1  189  2021-04-06  2021-07-06        SAC   0.057972   0.095592    0.046929
# 2  252  2021-07-06  2021-10-04        SAC  -0.010757  -0.058353   -0.023654
# 3  315  2021-10-04  2022-01-03        A2C   0.170435   0.039835    0.127433
#
#   SAC Sharpe TD3 Sharpe
# 0   0.253755   0.306572
# 1   0.187309   0.182612
# 2   0.045967  -0.022104
# 3   0.150804   0.161015

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
import pandas as pd

# Assuming these variables are already defined
# unique_trade_date, rebalance_window, validation_window

# Create DataFrame for trade dates
df_trade_date = pd.DataFrame({'datadate': unique_trade_date})

# Initialize an empty DataFrame for account values
df_account_value = pd.DataFrame()

# Read and concatenate CSV files
for i in range(rebalance_window + validation_window, len(unique_trade_date) + 1, rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble', i))
    df_account_value = pd.concat([df_account_value, temp], ignore_index=True)

# Calculate Sharpe Ratio
sharpe = (252 ** 0.5) * df_account_value.account_value.pct_change(1).mean() / df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio:', sharpe)

# Join DataFrames
df_account_value = df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       1 import pandas as pd
#       3 # Assuming these variables are already defined
#       4 # unique_trade_date, rebalance_window, validation_window
#       5
#       6 # Create DataFrame for trade dates
# ----> 7 df_trade_date = pd.DataFrame({'datadate': unique_trade_date})
#       9 # Initialize an empty DataFrame for account values
#      10 df_account_value = pd.DataFrame()
#
# NameError: name 'unique_trade_date' is not defined

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   9.999937e+05  2021-04-07     -0.000006  2021-04-07
# 2   9.999314e+05  2021-04-08     -0.000062  2021-04-08
# 3   1.001303e+06  2021-04-09      0.001372  2021-04-09
# 4   1.000515e+06  2021-04-12     -0.000787  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# c:\Python310\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
# ==============Get Backtest Results===========
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 22
#      19 print("==============Get Backtest Results===========")
#      20 now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')
# ---> 22 perf_stats_all = backtest_stats(account_value=df_account_value)
#      23 perf_stats_all = pd.DataFrame(perf_stats_all)
#
# NameError: name 'df_account_value' is not defined

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ==============Get Baseline Stats===========
# Shape of DataFrame:  (251, 8)
# Annual return          0.037486
# Cumulative returns     0.037335
# Annual volatility      0.134331
# Sharpe ratio           0.342028
# Calmar ratio           0.331049
# Stability              0.066383
# Max drawdown          -0.113235
# Omega ratio            1.058031
# Sortino ratio          0.480831
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.970301
# Daily value at risk   -0.016742
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# df_dji:             date           dji
# 0    2021-04-06  1.000000e+06
# 1    2021-04-07  1.000479e+06
# 2    2021-04-08  1.002194e+06
# 3    2021-04-09  1.011079e+06
# 4    2021-04-12  1.009427e+06
# ..          ...           ...
# 247  2022-03-28  1.045637e+06
# 248  2022-03-29  1.055757e+06
# 249  2022-03-30  1.053801e+06
# 250  2022-03-31  1.037335e+06
# 251  2022-04-01           NaN
#
# [252 rows x 2 columns]
# df_dji:                       dji
# date
# 2021-04-06  1.000000e+06
# 2021-04-07  1.000479e+06
# 2021-04-08  1.002194e+06
# 2021-04-09  1.011079e+06
# 2021-04-12  1.009427e+06
# ...                  ...
# 2022-03-28  1.045637e+06
# 2022-03-29  1.055757e+06
# 2022-03-30  1.053801e+06
# 2022-03-31  1.037335e+06
# 2022-04-01           NaN
#
# [252 rows x 1 columns]

# %%
# print("==============Compare to DJIA===========")
# %matplotlib inline
# # S&P 500: ^GSPC
# # Dow Jones Index: ^DJI
# # NASDAQ 100: ^NDX
# backtest_plot(df_account_value,
#               baseline_ticker = '^DJI',
#               baseline_start = df_account_value.loc[0,'date'],
#               baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)

# df_result_ensemble.drop(df_result_ensemble.columns[0], axis = 1)
print("df_trade_date: ", df_trade_date)
# df_result_ensemble['date'] = df_trade_date['datadate']
# df_result_ensemble['account_value'] = df_account_value['account_value']
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
# result = pd.merge(result, df_result_ensemble, left_index=True, right_index=True)
# result = pd.merge(result, df_dji, left_index=True, right_index=True)
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

print(result)

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:         datadate
# 0    2021-01-04
# 1    2021-01-05
# 2    2021-01-06
# 3    2021-01-07
# 4    2021-01-08
# ..          ...
# 350  2022-05-24
# 351  2022-05-25
# 352  2022-05-26
# 353  2022-05-27
# 354  2022-05-31
#
# [355 rows x 1 columns]
# df_result_ensemble:                  ensemble
# date
# 2021-04-06  1.000000e+06
# 2021-04-07  9.999937e+05
# 2021-04-08  9.999314e+05
# 2021-04-09  1.001303e+06
# 2021-04-12  1.000515e+06
# ...                  ...
# 2022-03-28  1.048540e+06
# 2022-03-29  1.062819e+06
# 2022-03-30  1.049422e+06
# 2022-03-31  1.031126e+06
# 2022-04-01  1.037415e+06
#
# [252 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                  ensemble           dji
# date
# 2021-04-06  1.000000e+06  1.000000e+06
# 2021-04-07  9.999937e+05  1.000479e+06
# 2021-04-08  9.999314e+05  1.002194e+06
# 2021-04-09  1.001303e+06  1.011079e+06
# 2021-04-12  1.000515e+06  1.009427e+06
# ...                  ...           ...
# 2022-03-28  1.048540e+06  1.045637e+06
# 2022-03-29  1.062819e+06  1.055757e+06
# 2022-03-30  1.049422e+06  1.053801e+06
# 2022-03-31  1.031126e+06  1.037335e+06
# 2022-04-01  1.037415e+06           NaN
#
# [252 rows x 2 columns]
#                 ensemble           dji
# date
# 2021-04-06  1.000000e+06  1.000000e+06
# 2021-04-07  9.999937e+05  1.000479e+06
# 2021-04-08  9.999314e+05  1.002194e+06
# 2021-04-09  1.001303e+06  1.011079e+06
# 2021-04-12  1.000515e+06  1.009427e+06
# ...                  ...           ...
# 2022-03-28  1.048540e+06  1.045637e+06
# 2022-03-29  1.062819e+06  1.055757e+06
# 2022-03-30  1.049422e+06  1.053801e+06
# 2022-03-31  1.031126e+06  1.037335e+06
# 2022-04-01  1.037415e+06           NaN
#
# [252 rows x 2 columns]
