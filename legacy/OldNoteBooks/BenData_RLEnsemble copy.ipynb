# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
# import condacolab
# condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
# TODO, remove DOW from training as it is missing some values in 2019
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

# TRAIN_START_DATE = '2010-01-01'
# TRAIN_END_DATE = '2021-10-01'
# TEST_START_DATE = '2021-10-01'
# TEST_END_DATE = '2023-03-01'
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.config_tickers import DOW_30_TICKER


# TODO Drop the DOW stock
value_to_remove = "DOW"
# Create a new list without the specified string
DOW_30_TICKER = [x for x in DOW_30_TICKER if x != value_to_remove]
print(DOW_30_TICKER)

# TODO try different date ranges
# TRAIN_START_DATE = '2009-01-01'
# TRAIN_END_DATE = '2018-10-01'
# TEST_START_DATE = '2018-10-01'
# TEST_END_DATE = '2021-03-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS']
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (96135, 8)

# %%
INDICATORS = ['macd',
            'rsi_30',
            'cci_30',
            'dx_30']

# %%
from finrl.meta.preprocessor.preprocessors import FeatureEngineer
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)

# here you can see the engineered features are added to each stock day
print(processed)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index
#              date        open        high         low       close     volume  \
# 0      2009-04-01    3.717500    3.892857    3.710357    3.278072  589372000
# 1      2009-04-01   48.779999   48.930000   47.099998   34.259613   10850100
# 2      2009-04-01   13.340000   14.640000   13.080000   11.463929   27701800
# 3      2009-04-01   34.520000   35.599998   34.209999   26.850742    9288800
# 4      2009-04-01   27.500000   29.520000   27.440001   19.184853   15308300
# ...           ...         ...         ...         ...         ...        ...
# 96130  2022-05-31  503.619995  504.109985  495.660004  479.012299    4003100
# 96131  2022-05-31  210.380005  214.350006  209.110001  208.462799    9586400
# 96132  2022-05-31   51.259998   51.560001   50.849998   43.505821   25016600
# 96133  2022-05-31   43.480000   44.270000   43.049999   38.039917    8192000
# 96134  2022-05-31   42.486668   43.299999   42.473331   41.486992   36912300
#
#         tic  day      macd      rsi_30     cci_30       dx_30  turbulence
# 0      AAPL    2  0.000000  100.000000  66.666667  100.000000    0.000000
# 1      AMGN    2  0.000000  100.000000  66.666667  100.000000    0.000000
# 2       AXP    2  0.000000  100.000000  66.666667  100.000000    0.000000
# 3        BA    2  0.000000  100.000000  66.666667  100.000000    0.000000
# 4       CAT    2  0.000000  100.000000  66.666667  100.000000    0.000000
# ...     ...  ...       ...         ...        ...         ...         ...
# 96130   UNH    1 -2.724974   49.351047 -15.116973   16.342870   33.827773
# 96131     V    1 -0.150034   51.484929  56.314483   13.501659   33.827773
# 96132    VZ    1  0.202576   52.638150  66.494869    3.544938   33.827773
# 96133   WBA    1 -0.255385   48.859379  10.607954    7.879621   33.827773
# 96134   WMT    1 -2.239190   39.207318 -79.119092   32.485563   33.827773
#
# [96135 rows x 13 columns]

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 175

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS, # TODO we pass these in and set the environment
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity":5

}

# buy_cost_list = sell_cost_list = [0.001] * stock_dimension
# num_stock_shares = [0] * stock_dimension
# env_kwargs = {
#     "hmax": 100,
#     "initial_amount": 1000000,
#     "num_stock_shares": num_stock_shares,
#     "buy_cost_pct": buy_cost_list,
#     "sell_cost_pct": sell_cost_list,
#     "state_space": state_space,
#     "stock_dim": stock_dimension,
#     "tech_indicator_list": INDICATORS,
#     "action_space": stock_dimension,
#     "reward_scaling": 1e-4
# }

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

# TODO here we pass in the engineered features along with the stock data
ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **env_kwargs)
# e_train_gym = StockTradingEnv(df = processed, **env_kwargs)
# agent = DRLAgent(e_train_gym)
# if_using_a2c = True
# model_a2c = agent.get_model("a2c")
# # if if_using_a2c:
# #   tmp_path = RESULTS_DIR + '/a2c'
# #   new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# #   model_a2c.set_logger(new_logger_a2c)
# trained_a2c = agent.train_model(model=model_a2c,
#                              tb_log_name='a2c',
#                              total_timesteps=50000)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
    "batch_size": 64,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

TD3_model_kwargs = {"batch_size": 100, "buffer_size": 1000000, "learning_rate": 0.0001}




timesteps_dict = {'a2c' : 10_000,
                 'ppo' : 10_000,
                 'ddpg' : 10_000,
                 'sac' : 10_000,
                 'td3' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  203.40433015366023
# ======Model training from:  2009-04-01 to  2021-01-04
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_7
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.319     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -41        |
# |    reward             | 0.40715137 |
# |    std                | 1.01       |
# |    value_loss         | 2.76       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.132    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 20.5      |
# |    reward             | 4.2668915 |
# |    std                | 1.01      |
# |    value_loss         | 0.442     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 88       |
# |    iterations         | 300      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -235     |
# |    reward             | 4.578432 |
# |    std                | 1.01     |
# |    value_loss         | 38.6     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 400        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 28.8       |
# |    reward             | 0.09379356 |
# |    std                | 1.01       |
# |    value_loss         | 3.7        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 91          |
# |    iterations         | 500         |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -80.8       |
# |    reward             | -0.96767795 |
# |    std                | 1.01        |
# |    value_loss         | 6.08        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 600       |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.341    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -11.8     |
# |    reward             | 1.0185614 |
# |    std                | 1.01      |
# |    value_loss         | 1.21      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 700       |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 1.92      |
# |    reward             | -1.218732 |
# |    std                | 1.01      |
# |    value_loss         | 0.56      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 800        |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 17.6       |
# |    reward             | -0.8921959 |
# |    std                | 1.01       |
# |    value_loss         | 0.535      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 900       |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 45.5      |
# |    reward             | 2.2728925 |
# |    std                | 1.01      |
# |    value_loss         | 2.51      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 1000     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 45.5     |
# |    reward             | 1.416303 |
# |    std                | 1.01     |
# |    value_loss         | 1.34     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 1100       |
# |    time_elapsed       | 58         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -66.5      |
# |    reward             | 0.77404565 |
# |    std                | 1.01       |
# |    value_loss         | 4.4        |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 94           |
# |    iterations         | 1200         |
# |    time_elapsed       | 63           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -41.4        |
# |    explained_variance | -0.00035     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | 96.3         |
# |    reward             | -0.039347243 |
# |    std                | 1.01         |
# |    value_loss         | 6.79         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 93          |
# |    iterations         | 1300        |
# |    time_elapsed       | 69          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | -36.3       |
# |    reward             | -0.23395757 |
# |    std                | 1.01        |
# |    value_loss         | 1.68        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 1400       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 57         |
# |    reward             | -0.7705115 |
# |    std                | 1.01       |
# |    value_loss         | 3.63       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 1500      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 35.5      |
# |    reward             | 2.8736355 |
# |    std                | 1.01      |
# |    value_loss         | 3.42      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 1600       |
# |    time_elapsed       | 86         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 42.2       |
# |    reward             | -0.7318927 |
# |    std                | 1.01       |
# |    value_loss         | 2.02       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 1700      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -148      |
# |    reward             | 3.9307287 |
# |    std                | 1.01      |
# |    value_loss         | 21.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1800       |
# |    time_elapsed       | 98         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -6.77      |
# |    reward             | 0.14031811 |
# |    std                | 1.01       |
# |    value_loss         | 0.115      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 1900      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -23.1     |
# |    reward             | 1.7615343 |
# |    std                | 1         |
# |    value_loss         | 3.19      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 90          |
# |    iterations         | 2000        |
# |    time_elapsed       | 110         |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -42.9       |
# |    reward             | -0.19606854 |
# |    std                | 1.01        |
# |    value_loss         | 1.65        |
# ---------------------------------------
# ======a2c Validation from:  2021-01-04 to  2021-04-06
# a2c Sharpe Ratio:  0.23852359302903164
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_7
# day: 2959, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4558459.37
# total_reward: 3558459.37
# total_cost: 5300.45
# total_trades: 51375
# Sharpe: 0.835
# =================================
# ======ddpg Validation from:  2021-01-04 to  2021-04-06
# ddpg Sharpe Ratio:  0.2519423513497823
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cpu device
# Logging to tensorboard_log/td3\td3_126_7
# day: 2959, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 6490388.46
# total_reward: 5490388.46
# total_cost: 1636.68
# total_trades: 47748
# Sharpe: 0.978
# =================================
# ======td3 Validation from:  2021-01-04 to  2021-04-06
# td3 Sharpe Ratio:  0.40922085784079093
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac\sac_126_7
# day: 2959, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 3911672.42
# total_reward: 2911672.42
# total_cost: 215801.17
# total_trades: 59450
# Sharpe: 0.702
# =================================
# ======sac Validation from:  2021-01-04 to  2021-04-06
# sac Sharpe Ratio:  0.14504106851538998
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_7
# ----------------------------------
# | time/              |           |
# |    fps             | 118       |
# |    iterations      | 1         |
# |    time_elapsed    | 17        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.0043277 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 2           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015248437 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00233     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.51        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0297     |
# |    reward               | 1.0692699   |
# |    std                  | 1           |
# |    value_loss           | 8.6         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 3            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.013555781  |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.2        |
# |    explained_variance   | 0.00744      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18.7         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0222      |
# |    reward               | -0.012810404 |
# |    std                  | 1            |
# |    value_loss           | 39.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 4           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015588643 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00533    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 36.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.023      |
# |    reward               | -3.4914892  |
# |    std                  | 1           |
# |    value_loss           | 76.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 5           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016137896 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.0179      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0262     |
# |    reward               | 1.0049706   |
# |    std                  | 1           |
# |    value_loss           | 19.4        |
# -----------------------------------------
# ======ppo Validation from:  2021-01-04 to  2021-04-06
# ppo Sharpe Ratio:  0.33068879560624537
# ======Best Model Retraining from:  2009-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  203.40433015366023
# ======Model training from:  2009-04-01 to  2021-04-06
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_7
# --------------------------------------
# | time/                 |            |
# |    fps                | 106        |
# |    iterations         | 100        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -116       |
# |    reward             | -0.5722558 |
# |    std                | 1          |
# |    value_loss         | 13         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 200       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -51.8     |
# |    reward             | 4.2701015 |
# |    std                | 1         |
# |    value_loss         | 2.31      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -166      |
# |    reward             | 5.2710676 |
# |    std                | 1         |
# |    value_loss         | 22.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 400        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.11      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 10         |
# |    reward             | 0.33439314 |
# |    std                | 1          |
# |    value_loss         | 3.86       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 95          |
# |    iterations         | 500         |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -443        |
# |    reward             | -0.73239535 |
# |    std                | 1           |
# |    value_loss         | 142         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 91        |
# |    iterations         | 600       |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -111      |
# |    reward             | -3.359857 |
# |    std                | 1.01      |
# |    value_loss         | 18.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 700       |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0329   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 46        |
# |    reward             | -3.348355 |
# |    std                | 1.01      |
# |    value_loss         | 2.71      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 800        |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.00286    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 13.3       |
# |    reward             | 0.33268338 |
# |    std                | 1.01       |
# |    value_loss         | 0.999      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 900       |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 195       |
# |    reward             | 5.2557564 |
# |    std                | 1.01      |
# |    value_loss         | 32.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 1000      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 17.8      |
# |    reward             | 1.6529864 |
# |    std                | 1.01      |
# |    value_loss         | 0.978     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1100      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.000378  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -194      |
# |    reward             | 3.9950938 |
# |    std                | 1.01      |
# |    value_loss         | 35.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1200      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.0689    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 268       |
# |    reward             | 7.4703574 |
# |    std                | 1.01      |
# |    value_loss         | 55        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 1300       |
# |    time_elapsed       | 68         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 46.9       |
# |    reward             | -2.5108566 |
# |    std                | 1.01       |
# |    value_loss         | 2.77       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1400      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 28        |
# |    reward             | 1.4016341 |
# |    std                | 1.01      |
# |    value_loss         | 2.91      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1500      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -138      |
# |    reward             | -7.841857 |
# |    std                | 1.01      |
# |    value_loss         | 11.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1600      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -126      |
# |    reward             | 3.0190182 |
# |    std                | 1         |
# |    value_loss         | 20.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1700      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -1.65e+03 |
# |    reward             | 5.71644   |
# |    std                | 1.01      |
# |    value_loss         | 1.74e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 1800     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 113      |
# |    reward             | 2.720474 |
# |    std                | 1        |
# |    value_loss         | 11.1     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 93          |
# |    iterations         | 1900        |
# |    time_elapsed       | 101         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -0.0658     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 14          |
# |    reward             | -0.35912374 |
# |    std                | 1           |
# |    value_loss         | 1.27        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 2000      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -48.7     |
# |    reward             | 1.2119246 |
# |    std                | 1.01      |
# |    value_loss         | 2.48      |
# -------------------------------------
# ======a2c Validation from:  2021-04-06 to  2021-07-06
# a2c Sharpe Ratio:  0.11414027320076828
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_7
# day: 3022, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4578455.23
# total_reward: 3578455.23
# total_cost: 5392.83
# total_trades: 32186
# Sharpe: 0.775
# =================================
# ======ddpg Validation from:  2021-04-06 to  2021-07-06
# ddpg Sharpe Ratio:  0.35298354840016977
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cpu device
# Logging to tensorboard_log/td3\td3_189_7
# day: 3022, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 6145068.96
# total_reward: 5145068.96
# total_cost: 1232.09
# total_trades: 57275
# Sharpe: 0.937
# =================================
# ======td3 Validation from:  2021-04-06 to  2021-07-06
# td3 Sharpe Ratio:  0.16920049817018978
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac\sac_189_7
# day: 3022, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 7126943.15
# total_reward: 6126943.15
# total_cost: 100739.69
# total_trades: 54457
# Sharpe: 0.951
# =================================
# ======sac Validation from:  2021-04-06 to  2021-07-06
# sac Sharpe Ratio:  0.0907965202987208
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_7
# ----------------------------------
# | time/              |           |
# |    fps             | 112       |
# |    iterations      | 1         |
# |    time_elapsed    | 18        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.9081104 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 2           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015731532 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00574     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.21        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0284     |
# |    reward               | 0.6366233   |
# |    std                  | 1           |
# |    value_loss           | 11.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 3           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013745878 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00422     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 60.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0145     |
# |    reward               | 0.47180343  |
# |    std                  | 1           |
# |    value_loss           | 89.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 4           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012460045 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0249     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 77.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | -0.6985845  |
# |    std                  | 1           |
# |    value_loss           | 83.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 106        |
# |    iterations           | 5          |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01886502 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | -0.0154    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 7.81       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.022     |
# |    reward               | 0.6327635  |
# |    std                  | 1.01       |
# |    value_loss           | 15.6       |
# ----------------------------------------
# ======ppo Validation from:  2021-04-06 to  2021-07-06
# ppo Sharpe Ratio:  0.12899113023655248
# ======Best Model Retraining from:  2009-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  203.40433015366023
# ======Model training from:  2009-04-01 to  2021-07-06
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_7
# ----------------------------------------
# | time/                 |              |
# |    fps                | 82           |
# |    iterations         | 100          |
# |    time_elapsed       | 6            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -41.2        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -4.56        |
# |    reward             | -0.054677207 |
# |    std                | 1            |
# |    value_loss         | 2.56         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 83        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0634   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 47.1      |
# |    reward             | 1.6700268 |
# |    std                | 1         |
# |    value_loss         | 1.98      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 300       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.0608   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -192      |
# |    reward             | 3.2553809 |
# |    std                | 1         |
# |    value_loss         | 28.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 400        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0353     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -5.49      |
# |    reward             | 0.32635814 |
# |    std                | 1          |
# |    value_loss         | 3.75       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 500        |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 71.5       |
# |    reward             | 0.68201244 |
# |    std                | 1          |
# |    value_loss         | 3.97       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 91        |
# |    iterations         | 600       |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.00967  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 444       |
# |    reward             | 3.2923427 |
# |    std                | 0.998     |
# |    value_loss         | 129       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 700        |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -216       |
# |    reward             | -0.3381954 |
# |    std                | 1          |
# |    value_loss         | 30.7       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 91          |
# |    iterations         | 800         |
# |    time_elapsed       | 43          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | -0.0147     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -221        |
# |    reward             | -0.31574294 |
# |    std                | 1           |
# |    value_loss         | 33.2        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 900        |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.05       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 107        |
# |    reward             | -0.6905801 |
# |    std                | 0.999      |
# |    value_loss         | 8.84       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1000       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.0264    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -33.2      |
# |    reward             | -0.5037667 |
# |    std                | 1          |
# |    value_loss         | 1.55       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1100       |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -62.7      |
# |    reward             | -1.7819351 |
# |    std                | 1          |
# |    value_loss         | 11.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1200       |
# |    time_elapsed       | 66         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -151       |
# |    reward             | -3.7704012 |
# |    std                | 1          |
# |    value_loss         | 23.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1300       |
# |    time_elapsed       | 72         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.568      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 44.8       |
# |    reward             | -1.6104987 |
# |    std                | 0.999      |
# |    value_loss         | 2.12       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1400      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 6.83      |
# |    reward             | 1.5756527 |
# |    std                | 1         |
# |    value_loss         | 1.33      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1500       |
# |    time_elapsed       | 83         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 47.6       |
# |    reward             | 0.14330336 |
# |    std                | 1          |
# |    value_loss         | 1.6        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1600      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0218   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -198      |
# |    reward             | 0.9652296 |
# |    std                | 1         |
# |    value_loss         | 50.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1700      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -3.11     |
# |    reward             | 1.7561251 |
# |    std                | 1         |
# |    value_loss         | 7.9       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 89       |
# |    iterations         | 1800     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -27.2    |
# |    reward             | 4.934434 |
# |    std                | 1        |
# |    value_loss         | 28.8     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1900       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# ...
# |    fps                | 80        |
# |    iterations         | 400       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -2.81     |
# |    reward             | 0.5865018 |
# |    std                | 0.996     |
# |    value_loss         | 3.83      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 500        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -0.217     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 153        |
# |    reward             | -0.3177153 |
# |    std                | 0.996      |
# |    value_loss         | 19.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 600       |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.000469  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 32        |
# |    reward             | -8.498807 |
# |    std                | 0.997     |
# |    value_loss         | 62        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 700        |
# |    time_elapsed       | 43         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0.00241    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -88.3      |
# |    reward             | -0.9353808 |
# |    std                | 0.996      |
# |    value_loss         | 8.73       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 800       |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -0.134    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 57.8      |
# |    reward             | 0.8793956 |
# |    std                | 0.995     |
# |    value_loss         | 3.01      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 900       |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.0175    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -31.9     |
# |    reward             | 2.4338698 |
# |    std                | 0.996     |
# |    value_loss         | 5.44      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 80          |
# |    iterations         | 1000        |
# |    time_elapsed       | 62          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | -1.84       |
# |    reward             | -0.45683038 |
# |    std                | 0.998       |
# |    value_loss         | 1.42        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 80       |
# |    iterations         | 1100     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 8.52e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 365      |
# |    reward             | 4.062467 |
# |    std                | 0.997    |
# |    value_loss         | 108      |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 81          |
# |    iterations         | 1200        |
# |    time_elapsed       | 73          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | 296         |
# |    reward             | -0.25940692 |
# |    std                | 0.996       |
# |    value_loss         | 73.1        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1300       |
# |    time_elapsed       | 78         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -14.5      |
# |    reward             | -1.0087987 |
# |    std                | 0.997      |
# |    value_loss         | 0.218      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 1400      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 16.7      |
# |    reward             | 0.5007822 |
# |    std                | 0.998     |
# |    value_loss         | 0.442     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 1500      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -98       |
# |    reward             | 0.73329   |
# |    std                | 0.999     |
# |    value_loss         | 6.16      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1600       |
# |    time_elapsed       | 96         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 55         |
# |    reward             | 0.93845624 |
# |    std                | 0.999      |
# |    value_loss         | 6.2        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1700       |
# |    time_elapsed       | 103        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -82.2      |
# |    reward             | 0.19461064 |
# |    std                | 1          |
# |    value_loss         | 5.47       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1800       |
# |    time_elapsed       | 109        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 20         |
# |    reward             | -1.5875418 |
# |    std                | 1          |
# |    value_loss         | 2.35       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1900       |
# |    time_elapsed       | 115        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -5.01      |
# |    reward             | 0.05341126 |
# |    std                | 1          |
# |    value_loss         | 0.0704     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 2000       |
# |    time_elapsed       | 122        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 3.08e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -105       |
# |    reward             | -2.4110951 |
# |    std                | 1          |
# |    value_loss         | 7.04       |
# --------------------------------------
# ======a2c Validation from:  2021-10-04 to  2022-01-03
# a2c Sharpe Ratio:  0.20911675184686238
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_315_7
# day: 3148, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4706226.32
# total_reward: 3706226.32
# total_cost: 5754.13
# total_trades: 39576
# Sharpe: 0.740
# =================================
# ======ddpg Validation from:  2021-10-04 to  2022-01-03
# ddpg Sharpe Ratio:  -0.00033874820120820384
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cpu device
# Logging to tensorboard_log/td3\td3_315_7
# day: 3148, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 14166678.93
# total_reward: 13166678.93
# total_cost: 3719.92
# total_trades: 10285
# Sharpe: 1.089
# =================================
# ======td3 Validation from:  2021-10-04 to  2022-01-03
# td3 Sharpe Ratio:  0.4941821861495438
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac\sac_315_7
# day: 3148, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 8835526.02
# total_reward: 7835526.02
# total_cost: 2472.62
# total_trades: 29004
# Sharpe: 1.057
# =================================
# ======sac Validation from:  2021-10-04 to  2022-01-03
# sac Sharpe Ratio:  0.2848340191874689
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_315_7
# ----------------------------------
# | time/              |           |
# |    fps             | 98        |
# |    iterations      | 1         |
# |    time_elapsed    | 20        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.9245535 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 2           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016113497 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0141     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.73        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0201     |
# |    reward               | 0.42825505  |
# |    std                  | 1           |
# |    value_loss           | 12.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 3           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019718427 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00078    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 65.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0156     |
# |    reward               | 5.5763946   |
# |    std                  | 1           |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 4           |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015224032 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00599    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0146     |
# |    reward               | -0.22165598 |
# |    std                  | 1           |
# |    value_loss           | 58.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 5           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014041584 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.97        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0215     |
# |    reward               | 0.2735269   |
# |    std                  | 1.01        |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ======ppo Validation from:  2021-10-04 to  2022-01-03
# ppo Sharpe Ratio:  0.3053991303597932
# ======Best Model Retraining from:  2009-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  63.5593768119812  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2021-01-04  2021-04-06        TD3   0.238524   0.330689    0.251942
# 1  189  2021-04-06  2021-07-06       DDPG    0.11414   0.128991    0.352984
# 2  252  2021-07-06  2021-10-04       DDPG  -0.072352  -0.048284    0.025916
# 3  315  2021-10-04  2022-01-03        TD3   0.209117   0.305399   -0.000339
#
#   SAC Sharpe TD3 Sharpe
# 0   0.145041   0.409221
# 1   0.090797     0.1692
# 2  -0.128659   0.012078
# 3   0.284834   0.494182

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
import pandas as pd

# Assuming these variables are already defined
# unique_trade_date, rebalance_window, validation_window

# Create DataFrame for trade dates
df_trade_date = pd.DataFrame({'datadate': unique_trade_date})

# Initialize an empty DataFrame for account values
df_account_value = pd.DataFrame()

# Read and concatenate CSV files
for i in range(rebalance_window + validation_window, len(unique_trade_date) + 1, rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble', i))
    df_account_value = pd.concat([df_account_value, temp], ignore_index=True)

# Calculate Sharpe Ratio
sharpe = (252 ** 0.5) * df_account_value.account_value.pct_change(1).mean() / df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio:', sharpe)

# Join DataFrames
df_account_value = df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio: 1.0634627473982023

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   9.997726e+05  2021-04-07     -0.000227  2021-04-07
# 2   9.997998e+05  2021-04-08      0.000027  2021-04-08
# 3   1.006086e+06  2021-04-09      0.006287  2021-04-09
# 4   1.005580e+06  2021-04-12     -0.000503  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.163023
# Cumulative returns     0.163023
# Annual volatility      0.153650
# Sharpe ratio           1.063463
# Calmar ratio           1.999550
# Stability              0.767015
# Max drawdown          -0.081530
# Omega ratio            1.206052
# Sortino ratio          1.632181
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.078724
# Daily value at risk   -0.018710
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ==============Get Baseline Stats===========
# Shape of DataFrame:  (251, 8)
# Annual return          0.037486
# Cumulative returns     0.037335
# Annual volatility      0.134331
# Sharpe ratio           0.342028
# Calmar ratio           0.331049
# Stability              0.066383
# Max drawdown          -0.113235
# Omega ratio            1.058031
# Sortino ratio          0.480831
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.970301
# Daily value at risk   -0.016742
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# df_dji:             date           dji
# 0    2021-04-06  1.000000e+06
# 1    2021-04-07  1.000479e+06
# 2    2021-04-08  1.002194e+06
# 3    2021-04-09  1.011079e+06
# 4    2021-04-12  1.009427e+06
# ..          ...           ...
# 247  2022-03-28  1.045637e+06
# 248  2022-03-29  1.055757e+06
# 249  2022-03-30  1.053801e+06
# 250  2022-03-31  1.037335e+06
# 251  2022-04-01           NaN
#
# [252 rows x 2 columns]
# df_dji:                       dji
# date
# 2021-04-06  1.000000e+06
# 2021-04-07  1.000479e+06
# 2021-04-08  1.002194e+06
# 2021-04-09  1.011079e+06
# 2021-04-12  1.009427e+06
# ...                  ...
# 2022-03-28  1.045637e+06
# 2022-03-29  1.055757e+06
# 2022-03-30  1.053801e+06
# 2022-03-31  1.037335e+06
# 2022-04-01           NaN
#
# [252 rows x 1 columns]

# %%
# print("==============Compare to DJIA===========")
# %matplotlib inline
# # S&P 500: ^GSPC
# # Dow Jones Index: ^DJI
# # NASDAQ 100: ^NDX
# backtest_plot(df_account_value,
#               baseline_ticker = '^DJI',
#               baseline_start = df_account_value.loc[0,'date'],
#               baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)

# df_result_ensemble.drop(df_result_ensemble.columns[0], axis = 1)
print("df_trade_date: ", df_trade_date)
# df_result_ensemble['date'] = df_trade_date['datadate']
# df_result_ensemble['account_value'] = df_account_value['account_value']
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
# result = pd.merge(result, df_result_ensemble, left_index=True, right_index=True)
# result = pd.merge(result, df_dji, left_index=True, right_index=True)
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

print(result)

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:         datadate
# 0    2021-01-04
# 1    2021-01-05
# 2    2021-01-06
# 3    2021-01-07
# 4    2021-01-08
# ..          ...
# 350  2022-05-24
# 351  2022-05-25
# 352  2022-05-26
# 353  2022-05-27
# 354  2022-05-31
#
# [355 rows x 1 columns]
# df_result_ensemble:                  ensemble
# date
# 2021-04-06  1.000000e+06
# 2021-04-07  9.997726e+05
# 2021-04-08  9.997998e+05
# 2021-04-09  1.006086e+06
# 2021-04-12  1.005580e+06
# ...                  ...
# 2022-03-28  1.169518e+06
# 2022-03-29  1.175855e+06
# 2022-03-30  1.182705e+06
# 2022-03-31  1.160672e+06
# 2022-04-01  1.163023e+06
#
# [252 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                  ensemble           dji
# date
# 2021-04-06  1.000000e+06  1.000000e+06
# 2021-04-07  9.997726e+05  1.000479e+06
# 2021-04-08  9.997998e+05  1.002194e+06
# 2021-04-09  1.006086e+06  1.011079e+06
# 2021-04-12  1.005580e+06  1.009427e+06
# ...                  ...           ...
# 2022-03-28  1.169518e+06  1.045637e+06
# 2022-03-29  1.175855e+06  1.055757e+06
# 2022-03-30  1.182705e+06  1.053801e+06
# 2022-03-31  1.160672e+06  1.037335e+06
# 2022-04-01  1.163023e+06           NaN
#
# [252 rows x 2 columns]
#                 ensemble           dji
# date
# 2021-04-06  1.000000e+06  1.000000e+06
# 2021-04-07  9.997726e+05  1.000479e+06
# 2021-04-08  9.997998e+05  1.002194e+06
# 2021-04-09  1.006086e+06  1.011079e+06
# 2021-04-12  1.005580e+06  1.009427e+06
# ...                  ...           ...
# 2022-03-28  1.169518e+06  1.045637e+06
# 2022-03-29  1.175855e+06  1.055757e+06
# 2022-03-30  1.182705e+06  1.053801e+06
# 2022-03-31  1.160672e+06  1.037335e+06
# 2022-04-01  1.163023e+06           NaN
#
# [252 rows x 2 columns]
