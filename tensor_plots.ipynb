# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/ppo_6_rew.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value']*1e+4)

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Average Reward')
plt.title('Average Episodic Reward')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732006e+09  14336 -0.000139
# 1  1.732006e+09  16384 -0.000142
# 2  1.732006e+09  24576 -0.000163
# 3  1.732006e+09  26624 -0.000170
# 4  1.732006e+09  32768 -0.000171

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/ppo_6_value_loss.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value'])

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Value Loss')
plt.title('Value Loss')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732006e+09  14336  0.000020
# 1  1.732006e+09  16384  0.000021
# 2  1.732006e+09  24576  0.000016
# 3  1.732006e+09  26624  0.000003
# 4  1.732006e+09  32768  0.000005

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/ppo_6_std.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value'])

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Standard Deviation')
plt.title('Policy Standard Deviation')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732006e+09  14336  0.979138
# 1  1.732006e+09  16384  0.979675
# 2  1.732006e+09  24576  0.958143
# 3  1.732006e+09  26624  0.955476
# 4  1.732006e+09  32768  0.937979

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/ppo_6_exp_var.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value'])

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Explained Variance')
plt.title('Explained Variance')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732006e+09  14336  0.938525
# 1  1.732006e+09  16384  0.859412
# 2  1.732006e+09  24576  0.852013
# 3  1.732006e+09  26624  0.884226
# 4  1.732006e+09  32768  0.873567

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/actions455_eiie_2019.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df = df.rename(columns={old_name: i for i, old_name in enumerate(df.columns)})
print(df)


import plotly.graph_objects as go


# Example data (replace with your actual data)
# Ensure data is available and correct
time = df.index

# Calculate cumulative sums for stacking
cash = df[0]
w1 = cash + df[1]
w2 = w1 + df[2]
w3 = w2 + df[3]
w4 = w3 + df[4]
w5 = w4 + df[5]
w6 = w5 + df[6]


# Create the figure
fig = go.Figure()

# Add each trace with fill specified to stack them

# This should stack up to the total load

fig.add_trace(go.Scatter(x=time, y=cash, fill='tozeroy', mode='none', name='Cash'))
fig.add_trace(go.Scatter(x=time, y=w1, fill='tonexty', mode='none', name='AAPL'))
fig.add_trace(go.Scatter(x=time, y=w2, fill='tonexty', mode='none', name='BA'))
fig.add_trace(go.Scatter(x=time, y=w3, fill='tonexty', mode='none', name='INTC'))
fig.add_trace(go.Scatter(x=time, y=w4, fill='tonexty', mode='none', name='MSFT'))
fig.add_trace(go.Scatter(x=time, y=w5, fill='tonexty', mode='none', name='V'))
fig.add_trace(go.Scatter(x=time, y=w6, fill='tonexty', mode='none', name='WMT'))
# fig.add_trace(go.Scatter(x=time, y=load, fill='tonexty', mode='none', name='load'))



# Customize layout
fig.update_layout(
    title='EIIE - Portfolio Weights - OOS 2020-03-13 to 2021-12-30',
    yaxis_title='Weights',
    xaxis_title='Time',
    legend_title='Stock',
    hovermode='x unified'
)

fig.show()
# Out:
#             0         1         2         3         4         5         6
# 0    0.001109  0.227760  0.154226  0.154226  0.154226  0.154226  0.154226
# 1    0.001181  0.104556  0.080509  0.203438  0.203438  0.203438  0.203438
# 2    0.001191  0.116841  0.003436  0.219633  0.219633  0.219633  0.219633
# 3    0.001111  0.160427  0.000438  0.209506  0.209506  0.209506  0.209506
# 4    0.001046  0.205562  0.015580  0.194453  0.194453  0.194453  0.194453
# ..        ...       ...       ...       ...       ...       ...       ...
# 449  0.000000  0.000000  0.999973  0.000027  0.000000  0.000000  0.000000
# 450  0.000000  0.000000  0.999948  0.000052  0.000000  0.000000  0.000000
# 451  0.000000  0.000000  0.999706  0.000293  0.000000  0.000000  0.000000
# 452  0.000000  0.000000  0.999733  0.000267  0.000000  0.000000  0.000000
# 453  0.000000  0.000000  0.999561  0.000439  0.000000  0.000000  0.000000
#
# [454 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/actions454_eiie_2020.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df = df.rename(columns={old_name: i for i, old_name in enumerate(df.columns)})
print(df)


import plotly.graph_objects as go


# Example data (replace with your actual data)
# Ensure data is available and correct
time = df.index

# Calculate cumulative sums for stacking
cash = df[0]
w1 = cash + df[1]
w2 = w1 + df[2]
w3 = w2 + df[3]
w4 = w3 + df[4]
w5 = w4 + df[5]
w6 = w5 + df[6]


# Create the figure
fig = go.Figure()

# Add each trace with fill specified to stack them

# This should stack up to the total load

fig.add_trace(go.Scatter(x=time, y=cash, fill='tozeroy', mode='none', name='Cash'))
fig.add_trace(go.Scatter(x=time, y=w1, fill='tonexty', mode='none', name='AAPL'))
fig.add_trace(go.Scatter(x=time, y=w2, fill='tonexty', mode='none', name='BA'))
fig.add_trace(go.Scatter(x=time, y=w3, fill='tonexty', mode='none', name='INTC'))
fig.add_trace(go.Scatter(x=time, y=w4, fill='tonexty', mode='none', name='MSFT'))
fig.add_trace(go.Scatter(x=time, y=w5, fill='tonexty', mode='none', name='V'))
fig.add_trace(go.Scatter(x=time, y=w6, fill='tonexty', mode='none', name='WMT'))
# fig.add_trace(go.Scatter(x=time, y=load, fill='tonexty', mode='none', name='load'))



# Customize layout
fig.update_layout(
    title='EIIE - Portfolio Weights - OOS 2021-03-16 to 2022-12-30',
    yaxis_title='Weights',
    xaxis_title='Time',
    legend_title='Stock',
    hovermode='x unified'
)

fig.show()
# Out:
#             0         1         2         3         4         5         6
# 0    0.132496  0.212358  0.110811  0.090992  0.194857  0.110860  0.147626
# 1    0.102617  0.242321  0.100591  0.083262  0.217372  0.103701  0.150136
# 2    0.100599  0.252759  0.093511  0.080223  0.224415  0.099307  0.149186
# 3    0.100013  0.257896  0.088629  0.078677  0.228351  0.096811  0.149623
# 4    0.099581  0.260388  0.085178  0.077725  0.231503  0.095324  0.150302
# ..        ...       ...       ...       ...       ...       ...       ...
# 448  0.272685  0.010590  0.025900  0.664200  0.017321  0.006372  0.002932
# 449  0.264159  0.010661  0.024696  0.674427  0.016960  0.006200  0.002896
# 450  0.281726  0.009256  0.021269  0.665568  0.014725  0.005107  0.002348
# 451  0.278562  0.009621  0.020722  0.668786  0.014802  0.005117  0.002390
# 452  0.271800  0.009875  0.020085  0.676037  0.014715  0.005068  0.002419
#
# [453 rows x 7 columns]

# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/better_rew.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value']*1e+4)

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Average Reward')
plt.title('Average Episodic Reward')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732592e+09  10240 -0.000018
# 1  1.732592e+09  14336 -0.000026
# 2  1.732592e+09  16384 -0.000030
# 3  1.732592e+09  20480 -0.000029
# 4  1.732592e+09  24576 -0.000032

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/better_val_loss.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value'])

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Value Loss')
plt.title('Value Loss')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732592e+09  10240  0.000168
# 1  1.732592e+09  14336  0.000012
# 2  1.732592e+09  16384  0.000031
# 3  1.732592e+09  20480  0.000014
# 4  1.732592e+09  24576  0.000007

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/better_std.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value'])

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Standard Deviation')
plt.title('Policy Standard Deviation')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732592e+09  10240  1.014144
# 1  1.732592e+09  14336  1.014144
# 2  1.732592e+09  16384  1.014144
# 3  1.732592e+09  20480  1.014144
# 4  1.732592e+09  24576  1.014144

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/better_exp_var.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the DataFrame
plt.plot(df['Step'], df['Value'])

# Customize the plot
plt.xlabel('Step')
plt.ylabel('Explained Variance')
plt.title('Explained Variance')
plt.grid(True)

# Show the plot
plt.show()
# Out:
#       Wall time   Step     Value
# 0  1.732592e+09  10240  0.909388
# 1  1.732592e+09  14336  0.960978
# 2  1.732592e+09  16384  0.901877
# 3  1.732592e+09  20480  0.930959
# 4  1.732592e+09  24576  0.926107

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/actions810_2019-2022.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df = df.rename(columns={old_name: i for i, old_name in enumerate(df.columns)})
print(df)


import plotly.graph_objects as go


# Example data (replace with your actual data)
# Ensure data is available and correct
time = df.index

# Calculate cumulative sums for stacking
cash = df[0]
w1 = cash + df[1]
w2 = w1 + df[2]
w3 = w2 + df[3]
w4 = w3 + df[4]
w5 = w4 + df[5]
w6 = w5 + df[6]


# Create the figure
fig = go.Figure()

# Add each trace with fill specified to stack them

# This should stack up to the total load

fig.add_trace(go.Scatter(x=time, y=cash, fill='tozeroy', mode='none', name='Cash'))
fig.add_trace(go.Scatter(x=time, y=w1, fill='tonexty', mode='none', name='AAPL'))
fig.add_trace(go.Scatter(x=time, y=w2, fill='tonexty', mode='none', name='BA'))
fig.add_trace(go.Scatter(x=time, y=w3, fill='tonexty', mode='none', name='INTC'))
fig.add_trace(go.Scatter(x=time, y=w4, fill='tonexty', mode='none', name='MSFT'))
fig.add_trace(go.Scatter(x=time, y=w5, fill='tonexty', mode='none', name='V'))
fig.add_trace(go.Scatter(x=time, y=w6, fill='tonexty', mode='none', name='WMT'))
# fig.add_trace(go.Scatter(x=time, y=load, fill='tonexty', mode='none', name='load'))



# Customize layout
fig.update_layout(
    title='PPO - Portfolio Weights - OOS 2019-03-14 to 2022-05-27',
    yaxis_title='Weights',
    xaxis_title='Time',
    legend_title='Stock',
    hovermode='x unified'
)

fig.show()
# Out:
#             0         1         2         3         4         5         6
# 0    0.078043  0.217973  0.084622  0.142701  0.254274  0.091952  0.130435
# 1    0.082287  0.213349  0.086997  0.143333  0.244798  0.095745  0.133491
# 2    0.072392  0.221615  0.078933  0.142749  0.264810  0.090689  0.128811
# 3    0.072623  0.225954  0.077096  0.142386  0.265083  0.088711  0.128147
# 4    0.074884  0.227242  0.079417  0.141444  0.260918  0.088302  0.127793
# ..        ...       ...       ...       ...       ...       ...       ...
# 804  0.045220  0.265100  0.068110  0.090722  0.399471  0.042056  0.089321
# 805  0.044408  0.263667  0.068324  0.089724  0.403436  0.041823  0.088619
# 806  0.044532  0.262352  0.068413  0.089194  0.405050  0.041247  0.089212
# 807  0.043702  0.264061  0.067771  0.089585  0.406075  0.040864  0.087942
# 808  0.043790  0.265405  0.067494  0.090120  0.404136  0.041364  0.087690
#
# [809 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/actions556_2022-2024.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df = df.rename(columns={old_name: i for i, old_name in enumerate(df.columns)})
print(df)


import plotly.graph_objects as go


# Example data (replace with your actual data)
# Ensure data is available and correct
time = df.index

# Calculate cumulative sums for stacking
cash = df[0]
w1 = cash + df[1]
w2 = w1 + df[2]
w3 = w2 + df[3]
w4 = w3 + df[4]
w5 = w4 + df[5]
w6 = w5 + df[6]


# Create the figure
fig = go.Figure()

# Add each trace with fill specified to stack them

# This should stack up to the total load

fig.add_trace(go.Scatter(x=time, y=cash, fill='tozeroy', mode='none', name='Cash'))
fig.add_trace(go.Scatter(x=time, y=w1, fill='tonexty', mode='none', name='AAPL'))
fig.add_trace(go.Scatter(x=time, y=w2, fill='tonexty', mode='none', name='BA'))
fig.add_trace(go.Scatter(x=time, y=w3, fill='tonexty', mode='none', name='INTC'))
fig.add_trace(go.Scatter(x=time, y=w4, fill='tonexty', mode='none', name='MSFT'))
fig.add_trace(go.Scatter(x=time, y=w5, fill='tonexty', mode='none', name='V'))
fig.add_trace(go.Scatter(x=time, y=w6, fill='tonexty', mode='none', name='WMT'))
# fig.add_trace(go.Scatter(x=time, y=load, fill='tonexty', mode='none', name='load'))



# Customize layout
fig.update_layout(
    title='PPO - Portfolio Weights - OOS 2022-03-13 to 2024-05-29',
    yaxis_title='Weights',
    xaxis_title='Time',
    legend_title='Stock',
    hovermode='x unified'
)

fig.show()
# Out:
#             0         1         2         3         4         5         6
# 0    0.120205  0.137520  0.132056  0.153989  0.206870  0.123750  0.125610
# 1    0.125760  0.143935  0.128520  0.149885  0.198229  0.125099  0.128573
# 2    0.128046  0.145381  0.128031  0.148350  0.195217  0.125775  0.129200
# 3    0.130177  0.145926  0.127577  0.147780  0.191195  0.126926  0.130419
# 4    0.131800  0.146755  0.126595  0.146939  0.188550  0.127751  0.131611
# ..        ...       ...       ...       ...       ...       ...       ...
# 550  0.102800  0.093177  0.112000  0.128828  0.223517  0.154217  0.185460
# 551  0.101547  0.090564  0.111581  0.128609  0.227720  0.153782  0.186197
# 552  0.100353  0.082994  0.114502  0.129338  0.226244  0.156867  0.189701
# 553  0.104667  0.090214  0.114653  0.129161  0.212112  0.158323  0.190870
# 554  0.104687  0.090730  0.114441  0.129307  0.211818  0.158345  0.190672
#
# [555 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/actions410_2023-2024.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df = df.rename(columns={old_name: i for i, old_name in enumerate(df.columns)})
print(df)


import plotly.graph_objects as go


# Example data (replace with your actual data)
# Ensure data is available and correct
time = df.index

# Calculate cumulative sums for stacking
cash = df[0]
w1 = cash + df[1]
w2 = w1 + df[2]
w3 = w2 + df[3]
w4 = w3 + df[4]
w5 = w4 + df[5]
w6 = w5 + df[6]


# Create the figure
fig = go.Figure()

# Add each trace with fill specified to stack them

# This should stack up to the total load

fig.add_trace(go.Scatter(x=time, y=cash, fill='tozeroy', mode='none', name='Cash'))
fig.add_trace(go.Scatter(x=time, y=w1, fill='tonexty', mode='none', name='AAPL'))
fig.add_trace(go.Scatter(x=time, y=w2, fill='tonexty', mode='none', name='BA'))
fig.add_trace(go.Scatter(x=time, y=w3, fill='tonexty', mode='none', name='INTC'))
fig.add_trace(go.Scatter(x=time, y=w4, fill='tonexty', mode='none', name='MSFT'))
fig.add_trace(go.Scatter(x=time, y=w5, fill='tonexty', mode='none', name='V'))
fig.add_trace(go.Scatter(x=time, y=w6, fill='tonexty', mode='none', name='WMT'))
# fig.add_trace(go.Scatter(x=time, y=load, fill='tonexty', mode='none', name='load'))



# Customize layout
fig.update_layout(
    title='PPO - Portfolio Weights - OOS 2022-03-13 to 2024-05-29',
    yaxis_title='Weights',
    xaxis_title='Time',
    legend_title='Stock',
    hovermode='x unified'
)

fig.show()
# Out:
#             0         1         2         3         4         5         6
# 0    0.192603  0.090776  0.151988  0.088183  0.157894  0.144619  0.173938
# 1    0.218923  0.081057  0.155998  0.084156  0.151067  0.138990  0.169809
# 2    0.211147  0.083115  0.157069  0.085351  0.150771  0.140588  0.171959
# 3    0.206561  0.085959  0.152393  0.086086  0.153639  0.145109  0.170252
# 4    0.198246  0.089394  0.149809  0.087019  0.155919  0.148729  0.170885
# ..        ...       ...       ...       ...       ...       ...       ...
# 404  0.205039  0.086672  0.201048  0.101491  0.119318  0.133195  0.153237
# 405  0.188155  0.094950  0.199843  0.109064  0.121772  0.135030  0.151186
# 406  0.183047  0.095464  0.202869  0.109672  0.121152  0.135857  0.151938
# 407  0.185583  0.093799  0.204292  0.108186  0.119922  0.135342  0.152877
# 408  0.177774  0.095677  0.208597  0.109419  0.119638  0.134000  0.154895
#
# [409 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the path to your CSV file
csv_file_path = 'tensor_graph/actions454_eiie_2020.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df = df.rename(columns={old_name: i for i, old_name in enumerate(df.columns)})
print(df)


import plotly.graph_objects as go


# Example data (replace with your actual data)
# Ensure data is available and correct
time = df.index

# Calculate cumulative sums for stacking
cash = df[0]
w1 = cash + df[1]
w2 = w1 + df[2]
w3 = w2 + df[3]
w4 = w3 + df[4]
w5 = w4 + df[5]
w6 = w5 + df[6]


# Create the figure
fig = go.Figure()

# Add each trace with fill specified to stack them

# This should stack up to the total load

fig.add_trace(go.Scatter(x=time, y=cash, fill='tozeroy', mode='none', name='Cash'))
fig.add_trace(go.Scatter(x=time, y=w1, fill='tonexty', mode='none', name='AMZN'))
fig.add_trace(go.Scatter(x=time, y=w2, fill='tonexty', mode='none', name='DIS'))
fig.add_trace(go.Scatter(x=time, y=w3, fill='tonexty', mode='none', name='IBM'))
fig.add_trace(go.Scatter(x=time, y=w4, fill='tonexty', mode='none', name='JPM'))
fig.add_trace(go.Scatter(x=time, y=w5, fill='tonexty', mode='none', name='NKE'))
fig.add_trace(go.Scatter(x=time, y=w6, fill='tonexty', mode='none', name='NVDA'))
# fig.add_trace(go.Scatter(x=time, y=load, fill='tonexty', mode='none', name='load'))



# Customize layout
fig.update_layout(
    title='EIIE - Portfolio Weights - OOS TODO to TODO',
    yaxis_title='Weights',
    xaxis_title='Time',
    legend_title='Stock',
    hovermode='x unified'
)

fig.show()
